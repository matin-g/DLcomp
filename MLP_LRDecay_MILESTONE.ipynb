# %% [markdown]
# ## Install the package dependencies before running this notebook

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import os, os.path 
import numpy 
import pickle
from glob import glob
import math

"""
    number of trajectories in each city
    # austin --  train: 43041 test: 6325 
    # miami -- train: 55029 test:7971
    # pittsburgh -- train: 43544 test: 6361
    # dearborn -- train: 24465 test: 3671
    # washington-dc -- train: 25744 test: 3829
    # palo-alto -- train:  11993 test:1686

    trajectories sampled at 10HZ rate, input 5 seconds, output 6 seconds
    
"""
# Out:
# '\n    number of trajectories in each city\n    # austin --  train: 43041 test: 6325 \n    # miami -- train: 55029 test:7971\n    # pittsburgh -- train: 43544 test: 6361\n    # dearborn -- train: 24465 test: 3671\n    # washington-dc -- train: 25744 test: 3829\n    # palo-alto -- train:  11993 test:1686\n\n    trajectories sampled at 10HZ rate, input 5 seconds, output 6 seconds\n    \n'

# %% [markdown]
# ## Create a Torch.Dataset class for the training dataset

# %%
from glob import glob
import pickle
import numpy as np
import torch.nn as nn
import torch.nn.functional as F

ROOT_PATH = "./"

cities = ["austin", "miami", "pittsburgh", "dearborn", "washington-dc", "palo-alto"]
splits = ["train", "test"]

def get_city_trajectories(city="palo-alto", split="train", valid=False, normalized=False):
    f_in = ROOT_PATH + split + "/" + city + "_inputs"
    inputs = pickle.load(open(f_in, "rb"))
    inputs = np.asarray(inputs)
    
    outputs = None
    
    if split=="train":
        f_out = ROOT_PATH + split + "/" + city + "_outputs"
        outputs = pickle.load(open(f_out, "rb"))
        outputs = np.asarray(outputs)
        
        if valid:
            idx = int(len(inputs) * .8)
            return inputs[:idx], inputs[idx:], outputs[:idx], outputs[idx:]

    return inputs, outputs

class ArgoverseDataset(Dataset):
    """Dataset class for Argoverse"""
    def __init__(self, city: str, split:str, transform=None):
        super(ArgoverseDataset, self).__init__()
        self.transform = transform
        self.split = split
        self.inputs, self.outputs = get_city_trajectories(city=city, split=split, normalized=False)

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        
        if self.split == 'train':
            data = (self.inputs[idx], self.outputs[idx])
        else:
            data = (self.inputs[idx])
            
        if self.transform:
            data = self.transform(data)

        return data
    
class ValidationDataset(Dataset):
    """Dataset class for Argoverse"""
    def __init__(self, inputs, outputs, transform=None):
        super(ValidationDataset, self).__init__()
        self.transform = transform
        self.inputs, self.outputs = inputs, outputs

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        
        data = (self.inputs[idx], self.outputs[idx])
            
        if self.transform:
            data = self.transform(data)

        return data

# intialize a dataset
city = 'palo-alto' 
split = 'train'
train_dataset  = ArgoverseDataset(city = city, split = split)

# %% [markdown]
# ## Create a DataLoader class for training

# %%
batch_sz = 32  # batch size 
train_loader = DataLoader(train_dataset, batch_size=batch_sz)

# %% [markdown]
# ## Sample a batch of data and visualize

# %%
import matplotlib.pyplot as plt
# import random

# def show_sample_batch(sample_batch):
#     """visualize the trajectory for a batch of samples"""
#     inp, out = sample_batch
#     batch_sz = inp.size(0)
#     agent_sz = inp.size(1)
    
#     fig, axs = plt.subplots(1, batch_sz, figsize=(15, 3), facecolor='w', edgecolor='k')
#     fig.subplots_adjust(hspace = .5, wspace=.001)
#     axs = axs.ravel()   
#     for i in range(batch_sz):
#         axs[i].xaxis.set_ticks([])
#         axs[i].yaxis.set_ticks([])
        
        # first two feature dimensions are (x,y) positions
#         axs[i].scatter(inp[i,:,0], inp[i,:,1])
#         axs[i].scatter(out[i,:,0], out[i,:,1])

        
# for i_batch, sample_batch in enumerate(train_loader):
#     # inp[i] is a scene with 50 coordinates, input[i, j] is a coordinate
#     # gotta loop through each scene in the batch
#     inp, out = sample_batch # inp: (batch size, 50, 2), out: (batch size, 60, 2)
#     """
#     TODO:
#       implement your Deep learning model
#       implement training routine
#     """
#     show_sample_batch(sample_batch)
#     break

# %%
# from d2l.ai
def grad_clipping(net, theta):
    """Clip the gradient."""
    if isinstance(net, nn.Module):
        params = [p for p in net.parameters() if p.requires_grad]
    else:
        params = net.params
    norm = torch.sqrt(sum(torch.sum((p.grad ** 2)) for p in params))
    if norm > theta:
        for param in params:
            param.grad[:] *= theta / norm


class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, n_layers, device, dropout=0):
        super(RNN, self).__init__()
        self.device = device
        self.rnn = nn.LSTM(
            input_size=input_size, 
            hidden_size=hidden_size, 
            num_layers=n_layers, 
            dropout=dropout, 
            batch_first=True
        )
        
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        x = x.to(self.device)
#         self.rnn.flatten_parameters()
                        
        out, (hn, cn) = self.rnn(x)
        
        print(out)
        
        o = hn[-1]
        
        print(self.fc(o))
        print(self.fc(o).size())

                        
        return self.fc(out)
    
    
import seaborn as sns
def train(net, n_epochs, train_loader, loss_fct, criterion, device, val_loader=None, valid=False):
    train_l= []
    val_l = []    
    for epoch in range(n_epochs):
        ## training loop
        for i_batch, batch in enumerate(train_loader):
            # inp[i] is a scene with 50 coordinates, input[i, j] is a coordinate
            inp, out = batch
            inp = inp.float().to(device)
            out = out.float().to(device)
            
            pred = net(inp).to(device)
            # print('input: {}'.format(inp[0, :3]))
            # print('preds: {}'.format(pred[0, :3]))
            # print('true: {}'.format(out[0, :3]))
            
            loss = loss_fct(pred, out)

            criterion.zero_grad()
            loss.backward()
            grad_clipping(net, 1)
            criterion.step()
            
        train_l.append(loss.item())
        
        if valid:
            for i_batch, batch in enumerate(val_loader):
                with torch.no_grad():
                    inp, out = batch
                    inp = inp.float().to(device)
                    out = out.float().to(device)

                    pred = net(inp).to(device)

                    val_loss = loss_fct(pred, out)
        if valid:
            val_l.append(val_loss.item())
            
            print('epoch: {}, training loss: {}, validation loss: {}'.format(epoch + 1, loss, val_loss))
        else:
            print('epoch: {}, training loss: {}'.format(epoch + 1, loss))
        
    
    fig, ax = plt.subplots(1, 2, figsize=(15, 10))
    sns.lineplot(ax=ax[0], x=np.arange(0, len(train_l)), y=train_l)
    if valid:
        sns.lineplot(ax=ax[1], x=np.arange(0, len(val_l)), y=val_l)
    print('-'* 70)
    return

# def predict(net, data_loader, device):
#     with torch.no_grad():
#         for i_batch, batch in enumerate(data_loader):
#             inp, _ = batch
#             inp = torch.cat((inp.float().to(device), torch.zeros(inp.size(0), 10, inp.size(2)).to(device)), dim=1)
                        
#             preds = net(inp.float().to(device))
            
#             return preds
        
def write_city_preds(net, test_loader, device, city, fp):       
    scene = 0
    output = ''

    with torch.no_grad():
        for i_batch, batch in enumerate(test_loader):
            inp = batch
            inp = inp.float().to(device)

            preds = net(inp)
            flat = preds[0].flatten().cpu().tolist()
            
            row = ['{}_{}'.format(scene, city)] + flat
            row = [str(i) for i in row]
            output += ','.join(row) + '\n'
            
            scene += 1
    
    try:
        with open('./submission.csv', 'a') as f:
            f.write(output)
        #print('Predictions for {} generated!'.format(city))
        return 1
    except:
        print('Error! Unsuccessful write...')
        return -1

# %% [markdown]
# ## These models were trained with SGD as the opto and it wasn't very good

# %%
# model = RNN(2, 256, 2).to(device)
# opto = torch.optim.SGD(model.parameters(), lr=1)
# loss_fct = nn.MSELoss()
# train(model, 100, train_loader, opto, loss_fct, device)

# %%
# model = RNN(2, 128, 2).to(device) 
# opto = torch.optim.SGD(model.parameters(), lr=1)
# loss_fct = nn.MSELoss()
# train(model, 100, train_loader, opto, loss_fct, device)

# %%
# model = RNN(2, 128, 2).to(device)
# opto = torch.optim.SGD(model.parameters(), lr=.1)
# loss_fct = nn.MSELoss()
# train(model, 100, train_loader, opto, loss_fct, device)

# %% [markdown]
# ## Started using Adam optimizer / lstm with dropout, these next 2 models are usable, adding l2 loss didnt converge, currently using the second one

# %%
# model = RNN(input_size=2, hidden_size=128, output_size=2, num_layers=2, dropout=.2).to(device)
# opto = torch.optim.Adam(model.parameters(), lr=.001)
# loss_fct = nn.MSELoss()

# train(model, 100, train_loader, opto, loss_fct, device)

# %%
# model = RNN(input_size=2, hidden_size=256, output_size=2, num_layers=2, dropout=.2).to(device)
# opto = torch.optim.Adam(model.parameters(), lr=.001)
# loss_fct = nn.MSELoss()

# train(model, 100, train_loader, opto, loss_fct, device)

# %% [markdown]
# ## Bidirectional doesn't make sense here

# %%
# model = RNN(2, 256, 2, .2, True).to(device)
# opto = torch.optim.Adam(model.parameters(), lr=.001, weight_decay=.01)
# loss_fct = nn.MSELoss()

# train(model, 100, train_loader, opto, loss_fct, device)

# %% [markdown]
# # Test Dataset and Predictions

# %%
def generate_submission(fp, model, n_epochs, batch_sz, opto, scheduler, loss_fct, device, valid=False):
    cities = ["austin", "miami", "pittsburgh", "dearborn", "washington-dc", "palo-alto"] 
    header = ['ID'] + ['v' + str(i) for i in range(0, 120)]
    
    with open(fp, 'w') as f:
        f.write(','.join(header) + '\n')

    for city in cities:
        if valid:
            i, v_i, o, v_o = get_city_trajectories(city=city, split="train", valid=valid)
            training_data = ValidationDataset(i, o)
            validation_data = ValidationDataset(v_i, v_o)
            train_loader = DataLoader(training_data, batch_size=batch_sz)
            val_loader = DataLoader(validation_data, batch_size=batch_sz)
        else:
            val_loader = None
            training_data = ArgoverseDataset(city=city, split='train')
            train_loader = DataLoader(training_data, batch_size=batch_sz)
        
#         train(model, n_epochs, train_loader, loss_fct, opto, device, val_loader, valid)
        train_mlp(model, n_epochs, train_loader, loss_fct, opto, scheduler, device, city, val_loader, valid)
        
        #if not valid:
        test_dataset  = ArgoverseDataset(city=city, split='test')
        test_loader = DataLoader(test_dataset, batch_size=1)

        write_city_preds(model, test_loader, device, city, fp)

        print("\nDone printing " + str(city) + " predictions")
        print('-'* 70)
        
    print(fp + ' generated!')

# %%
class MLP(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, device):
        super(MLP, self).__init__()
        self.device = device
        
        self.encoder = nn.Sequential(
            nn.Linear(100, 64, device=device),
            nn.ReLU(),
            nn.Linear(64, 32, device=device),
            nn.ReLU(),
            nn.Linear(32, 32, device=device)
        )
        
        self.decoder = nn.Sequential(
            nn.Linear(32, 64, device=device),
            nn.ReLU(),
            nn.Linear(64, 120, device=device),
            nn.ReLU(),
            nn.Linear(120, 120, device=device)
        )
        
    def forward(self, x):
        x = x.to(self.device)
        x = x.reshape(-1, x.size(1) * x.size(2)).float()
        x = self.encoder(x)
        x = self.decoder(x)
        x = x.reshape(-1, 60, 2) 
        return x

def train_mlp(net, n_epochs, train_loader, loss_fct, criterion, scheduler, device, city, val_loader=None, valid=False):
    train_l= []
    val_l = []
    for epoch in range(n_epochs):
        ## training loop
        for i_batch, batch in enumerate(train_loader):
            inp, out = batch
            inp = inp.float().to(device)
            out = out.float().to(device)
            
            pred = net(inp).to(device)
            
            loss = loss_fct(pred, out)

            criterion.zero_grad()
            loss.backward()
#             grad_clipping(net, 3)
            criterion.step()
        
        train_l.append(loss.item())
        
        if valid:    
            for i_batch, batch in enumerate(val_loader):
                with torch.no_grad():
                    inp, out = batch
                    inp = inp.float().to(device)
                    out = out.float().to(device)

                    pred = net(inp).to(device)

                    val_loss = loss_fct(pred, out)
        if valid:
            val_l.append(val_loss.item())
            
            print('epoch: {}, training loss: {}, validation loss: {}'.format(epoch + 1, loss, val_loss))
        else:
            print('epoch: {}, training loss: {}'.format(epoch + 1, loss))
        
        scheduler.step()
    fig, ax = plt.subplots(1, 2, figsize=(15, 10))
    sns.lineplot(ax=ax[0], x=np.arange(0, len(train_l)), y=train_l).set_title("Loss (MSE) for " + str(city))
    
    if valid:
        sns.lineplot(ax=ax[1], x=np.arange(0, len(val_l)), y=val_l).set_title("Loss (MSE) for " + str(city))
        
    return

# %%
#model = RNN(input_size=2, hidden_size=32, output_size=2, n_layers=2, device=device, dropout=.2).to(device)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = MLP(input_size=100, hidden_size=128, output_size=120, device=device).to(device)
opto = torch.optim.Adam(model.parameters(), lr = .0001)
scheduler = torch.optim.lr_scheduler.StepLR(opto, 100 , gamma=0.9)
loss_fct = nn.MSELoss()
 
generate_submission('./submission.csv', model, 300, 64, opto, scheduler, loss_fct, device, valid=True)
# Out:
# epoch: 1, training loss: 3563.96484375, validation loss: 4110.185546875
# epoch: 2, training loss: 1163.4398193359375, validation loss: 1651.7685546875
# epoch: 3, training loss: 936.6403198242188, validation loss: 1345.667724609375
# epoch: 4, training loss: 884.7625732421875, validation loss: 1236.5189208984375
# epoch: 5, training loss: 889.3134155273438, validation loss: 1124.765380859375
# epoch: 6, training loss: 899.8348388671875, validation loss: 1019.3798217773438
# epoch: 7, training loss: 920.1658935546875, validation loss: 959.7734375
# epoch: 8, training loss: 943.7811889648438, validation loss: 930.1140747070312
# epoch: 9, training loss: 925.13427734375, validation loss: 916.2396850585938
# epoch: 10, training loss: 877.698486328125, validation loss: 899.893310546875
# epoch: 11, training loss: 853.7426147460938, validation loss: 890.0263671875
# epoch: 12, training loss: 832.3694458007812, validation loss: 875.985107421875
# epoch: 13, training loss: 813.2818603515625, validation loss: 859.9280395507812
# epoch: 14, training loss: 783.2281494140625, validation loss: 845.0960693359375
# epoch: 15, training loss: 760.5982055664062, validation loss: 822.1663208007812
# epoch: 16, training loss: 739.7022705078125, validation loss: 804.88623046875
# epoch: 17, training loss: 726.0222778320312, validation loss: 780.2286987304688
# epoch: 18, training loss: 703.6072998046875, validation loss: 770.4193725585938
# epoch: 19, training loss: 680.2434692382812, validation loss: 751.2596435546875
# epoch: 20, training loss: 654.488037109375, validation loss: 728.025146484375
# epoch: 21, training loss: 626.8037719726562, validation loss: 703.42138671875
# epoch: 22, training loss: 597.2680053710938, validation loss: 684.86962890625
# epoch: 23, training loss: 560.06787109375, validation loss: 670.2872314453125
# epoch: 24, training loss: 522.970458984375, validation loss: 654.5068969726562
# epoch: 25, training loss: 454.9247741699219, validation loss: 672.913818359375
# epoch: 26, training loss: 412.305419921875, validation loss: 678.4392700195312
# epoch: 27, training loss: 389.51715087890625, validation loss: 680.8494262695312
# epoch: 28, training loss: 365.6628112792969, validation loss: 620.0146484375
# epoch: 29, training loss: 384.5715026855469, validation loss: 581.7496948242188
# epoch: 30, training loss: 344.95880126953125, validation loss: 535.4198608398438
# epoch: 31, training loss: 321.29779052734375, validation loss: 490.291015625
# epoch: 32, training loss: 294.6369934082031, validation loss: 459.6332702636719
# epoch: 33, training loss: 302.0083312988281, validation loss: 449.67626953125
# epoch: 34, training loss: 304.4866027832031, validation loss: 453.50762939453125
# epoch: 35, training loss: 286.41656494140625, validation loss: 449.2528076171875
# epoch: 36, training loss: 288.11407470703125, validation loss: 441.7841796875
# epoch: 37, training loss: 271.9461669921875, validation loss: 428.38446044921875
# epoch: 38, training loss: 290.0207824707031, validation loss: 427.5543518066406
# epoch: 39, training loss: 267.474853515625, validation loss: 405.5300598144531
# epoch: 40, training loss: 271.8590087890625, validation loss: 411.0993957519531
# epoch: 41, training loss: 260.3199462890625, validation loss: 394.3500061035156
# epoch: 42, training loss: 280.8357849121094, validation loss: 398.49163818359375
# epoch: 43, training loss: 266.6996765136719, validation loss: 387.2163391113281
# epoch: 44, training loss: 275.3084716796875, validation loss: 378.9133605957031
# epoch: 45, training loss: 258.28436279296875, validation loss: 365.49224853515625
# epoch: 46, training loss: 256.6822814941406, validation loss: 357.69866943359375
# epoch: 47, training loss: 254.6797637939453, validation loss: 349.681884765625
# epoch: 48, training loss: 248.07533264160156, validation loss: 332.67608642578125
# epoch: 49, training loss: 245.99069213867188, validation loss: 327.66217041015625
# epoch: 50, training loss: 232.43885803222656, validation loss: 324.721923828125
# epoch: 51, training loss: 218.40359497070312, validation loss: 322.59332275390625
# epoch: 52, training loss: 208.55482482910156, validation loss: 316.3839111328125
# epoch: 53, training loss: 202.11895751953125, validation loss: 313.11260986328125
# epoch: 54, training loss: 195.95005798339844, validation loss: 310.7091369628906
# epoch: 55, training loss: 193.59454345703125, validation loss: 299.47222900390625
# epoch: 56, training loss: 188.59716796875, validation loss: 300.46258544921875
# epoch: 57, training loss: 182.47056579589844, validation loss: 299.4812316894531
# epoch: 58, training loss: 174.3126678466797, validation loss: 299.8900451660156
# epoch: 59, training loss: 171.74789428710938, validation loss: 294.2869873046875
# epoch: 60, training loss: 170.6798858642578, validation loss: 280.243896484375
# epoch: 61, training loss: 178.68756103515625, validation loss: 280.9819030761719
# epoch: 62, training loss: 203.48956298828125, validation loss: 272.1071472167969
# epoch: 63, training loss: 205.81231689453125, validation loss: 273.28656005859375
# epoch: 64, training loss: 239.94906616210938, validation loss: 273.3565979003906
# epoch: 65, training loss: 234.72198486328125, validation loss: 283.44781494140625
# epoch: 66, training loss: 233.4815216064453, validation loss: 280.9822692871094
# epoch: 67, training loss: 235.67413330078125, validation loss: 277.32965087890625
# epoch: 68, training loss: 235.6975860595703, validation loss: 282.974609375
# epoch: 69, training loss: 227.0873565673828, validation loss: 279.4787292480469
# epoch: 70, training loss: 226.50997924804688, validation loss: 280.9222717285156
# epoch: 71, training loss: 213.21902465820312, validation loss: 293.3331298828125
# epoch: 72, training loss: 226.22488403320312, validation loss: 290.1075744628906
# epoch: 73, training loss: 223.58216857910156, validation loss: 284.08636474609375
# epoch: 74, training loss: 208.27174377441406, validation loss: 281.8831787109375
# epoch: 75, training loss: 199.78591918945312, validation loss: 283.7771911621094
# epoch: 76, training loss: 217.79953002929688, validation loss: 282.931640625
# epoch: 77, training loss: 213.0886688232422, validation loss: 284.4195556640625
# epoch: 78, training loss: 206.45616149902344, validation loss: 282.3709716796875
# epoch: 79, training loss: 203.12274169921875, validation loss: 290.6422119140625
# epoch: 80, training loss: 187.741943359375, validation loss: 292.08807373046875
# epoch: 81, training loss: 185.314208984375, validation loss: 292.3598327636719
# epoch: 82, training loss: 205.0083770751953, validation loss: 284.3485412597656
# epoch: 83, training loss: 201.57894897460938, validation loss: 290.6375427246094
# epoch: 84, training loss: 199.51025390625, validation loss: 287.8202209472656
# epoch: 85, training loss: 196.78787231445312, validation loss: 293.9761047363281
# epoch: 86, training loss: 186.98329162597656, validation loss: 284.170654296875
# epoch: 87, training loss: 195.1534423828125, validation loss: 292.0148620605469
# epoch: 88, training loss: 179.85658264160156, validation loss: 291.34857177734375
# epoch: 89, training loss: 186.95713806152344, validation loss: 291.9949645996094
# epoch: 90, training loss: 196.70420837402344, validation loss: 288.22625732421875
# epoch: 91, training loss: 174.5143280029297, validation loss: 287.4547119140625
# epoch: 92, training loss: 169.67799377441406, validation loss: 289.6606140136719
# epoch: 93, training loss: 186.4787139892578, validation loss: 286.1034240722656
# epoch: 94, training loss: 175.6916046142578, validation loss: 294.2130432128906
# epoch: 95, training loss: 183.94863891601562, validation loss: 289.44268798828125
# epoch: 96, training loss: 172.5560302734375, validation loss: 284.2281799316406
# epoch: 97, training loss: 176.0161590576172, validation loss: 285.9770202636719
# epoch: 98, training loss: 171.24002075195312, validation loss: 287.50341796875
# epoch: 99, training loss: 176.72036743164062, validation loss: 289.0353088378906
# epoch: 100, training loss: 184.25303649902344, validation loss: 280.0682678222656
# epoch: 101, training loss: 183.354736328125, validation loss: 221.79013061523438
# epoch: 102, training loss: 202.0326385498047, validation loss: 236.48043823242188
# epoch: 103, training loss: 198.20193481445312, validation loss: 239.5018768310547
# epoch: 104, training loss: 205.64793395996094, validation loss: 256.682861328125
# epoch: 105, training loss: 193.18141174316406, validation loss: 239.0541534423828
# epoch: 106, training loss: 204.10923767089844, validation loss: 245.40664672851562
# epoch: 107, training loss: 199.1911163330078, validation loss: 239.80148315429688
# epoch: 108, training loss: 205.01918029785156, validation loss: 243.41563415527344
# epoch: 109, training loss: 210.76211547851562, validation loss: 243.58163452148438
# epoch: 110, training loss: 202.9518280029297, validation loss: 235.15484619140625
# epoch: 111, training loss: 197.6419677734375, validation loss: 240.01739501953125
# epoch: 112, training loss: 206.69337463378906, validation loss: 235.76889038085938
# epoch: 113, training loss: 196.2772979736328, validation loss: 232.42559814453125
# epoch: 114, training loss: 209.43702697753906, validation loss: 232.56326293945312
# epoch: 115, training loss: 199.355224609375, validation loss: 225.89956665039062
# epoch: 116, training loss: 194.0537872314453, validation loss: 228.326904296875
# epoch: 117, training loss: 193.93614196777344, validation loss: 230.65658569335938
# epoch: 118, training loss: 195.975830078125, validation loss: 230.1442413330078
# epoch: 119, training loss: 202.33706665039062, validation loss: 229.42845153808594
# epoch: 120, training loss: 203.74755859375, validation loss: 223.3522186279297
# epoch: 121, training loss: 194.01211547851562, validation loss: 230.2702178955078
# epoch: 122, training loss: 199.8470458984375, validation loss: 240.21578979492188
# epoch: 123, training loss: 197.193115234375, validation loss: 230.37452697753906
# epoch: 124, training loss: 199.5191192626953, validation loss: 229.2724151611328
# epoch: 125, training loss: 204.2407684326172, validation loss: 232.8180389404297
# epoch: 126, training loss: 197.9416046142578, validation loss: 221.997314453125
# epoch: 127, training loss: 196.18199157714844, validation loss: 224.82215881347656
# epoch: 128, training loss: 193.7691192626953, validation loss: 221.2527618408203
# epoch: 129, training loss: 196.96820068359375, validation loss: 224.08694458007812
# epoch: 130, training loss: 201.2679901123047, validation loss: 226.19528198242188
# epoch: 131, training loss: 194.561767578125, validation loss: 222.26553344726562
# epoch: 132, training loss: 193.50868225097656, validation loss: 224.5561981201172
# epoch: 133, training loss: 201.59361267089844, validation loss: 224.24899291992188
# epoch: 134, training loss: 195.9790802001953, validation loss: 226.13644409179688
# epoch: 135, training loss: 190.3034210205078, validation loss: 218.31532287597656
# epoch: 136, training loss: 199.73220825195312, validation loss: 224.10142517089844
# epoch: 137, training loss: 187.14064025878906, validation loss: 219.2507781982422
# epoch: 138, training loss: 192.7487335205078, validation loss: 218.5356903076172
# epoch: 139, training loss: 191.20989990234375, validation loss: 216.51907348632812
# epoch: 140, training loss: 190.65072631835938, validation loss: 215.77650451660156
# epoch: 141, training loss: 200.5242919921875, validation loss: 222.31283569335938
# epoch: 142, training loss: 189.9310760498047, validation loss: 218.5380096435547
# epoch: 143, training loss: 195.9053192138672, validation loss: 219.21800231933594
# epoch: 144, training loss: 194.22659301757812, validation loss: 223.14468383789062
# epoch: 145, training loss: 190.0594482421875, validation loss: 220.28990173339844
# epoch: 146, training loss: 191.26351928710938, validation loss: 220.6191864013672
# epoch: 147, training loss: 192.93142700195312, validation loss: 218.06753540039062
# epoch: 148, training loss: 197.12107849121094, validation loss: 217.8827362060547
# epoch: 149, training loss: 185.98208618164062, validation loss: 213.74952697753906
# epoch: 150, training loss: 185.1201934814453, validation loss: 217.12741088867188
# epoch: 151, training loss: 185.42539978027344, validation loss: 214.3309783935547
# epoch: 152, training loss: 184.8515625, validation loss: 211.83355712890625
# epoch: 153, training loss: 188.8213348388672, validation loss: 213.1299591064453
# epoch: 154, training loss: 179.66192626953125, validation loss: 211.84637451171875
# epoch: 155, training loss: 180.04672241210938, validation loss: 212.6481170654297
# epoch: 156, training loss: 189.50308227539062, validation loss: 218.34031677246094
# epoch: 157, training loss: 191.493896484375, validation loss: 224.48895263671875
# epoch: 158, training loss: 184.5781707763672, validation loss: 215.6851806640625
# epoch: 159, training loss: 182.22109985351562, validation loss: 214.42727661132812
# epoch: 160, training loss: 184.5639190673828, validation loss: 215.85098266601562
# epoch: 161, training loss: 188.69525146484375, validation loss: 215.27098083496094
# epoch: 162, training loss: 183.98219299316406, validation loss: 212.81881713867188
# epoch: 163, training loss: 182.62257385253906, validation loss: 213.48033142089844
# epoch: 164, training loss: 181.9606170654297, validation loss: 211.63331604003906
# epoch: 165, training loss: 182.53997802734375, validation loss: 211.6034698486328
# epoch: 166, training loss: 184.5619659423828, validation loss: 212.19517517089844
# epoch: 167, training loss: 179.62179565429688, validation loss: 213.3390655517578
# epoch: 168, training loss: 179.38868713378906, validation loss: 215.8203125
# epoch: 169, training loss: 182.29965209960938, validation loss: 217.22581481933594
# epoch: 170, training loss: 189.8291778564453, validation loss: 215.80941772460938
# epoch: 171, training loss: 181.25640869140625, validation loss: 207.31097412109375
# epoch: 172, training loss: 181.46224975585938, validation loss: 212.20693969726562
# epoch: 173, training loss: 178.02891540527344, validation loss: 212.1645050048828
# epoch: 174, training loss: 178.40725708007812, validation loss: 214.50518798828125
# epoch: 175, training loss: 182.63760375976562, validation loss: 207.43521118164062
# epoch: 176, training loss: 172.7672882080078, validation loss: 208.0709228515625
# epoch: 177, training loss: 174.0992889404297, validation loss: 218.03469848632812
# epoch: 178, training loss: 181.10264587402344, validation loss: 218.40859985351562
# epoch: 179, training loss: 180.6983642578125, validation loss: 212.5324249267578
# epoch: 180, training loss: 181.29505920410156, validation loss: 213.57493591308594
# epoch: 181, training loss: 184.65838623046875, validation loss: 212.6068115234375
# epoch: 182, training loss: 179.12039184570312, validation loss: 212.81695556640625
# epoch: 183, training loss: 186.324462890625, validation loss: 210.54147338867188
# epoch: 184, training loss: 181.41680908203125, validation loss: 202.84408569335938
# epoch: 185, training loss: 179.82090759277344, validation loss: 212.26226806640625
# epoch: 186, training loss: 178.67965698242188, validation loss: 214.87738037109375
# epoch: 187, training loss: 179.85580444335938, validation loss: 208.2998046875
# epoch: 188, training loss: 180.63323974609375, validation loss: 213.99014282226562
# epoch: 189, training loss: 179.3473358154297, validation loss: 207.9836883544922
# epoch: 190, training loss: 178.3486785888672, validation loss: 200.60740661621094
# epoch: 191, training loss: 172.6465301513672, validation loss: 203.94554138183594
# epoch: 192, training loss: 178.574462890625, validation loss: 205.86447143554688
# epoch: 193, training loss: 183.8131866455078, validation loss: 212.71983337402344
# epoch: 194, training loss: 172.81349182128906, validation loss: 203.1149139404297
# epoch: 195, training loss: 180.49757385253906, validation loss: 204.9475860595703
# epoch: 196, training loss: 173.431396484375, validation loss: 197.3544921875
# epoch: 197, training loss: 179.10317993164062, validation loss: 204.0277557373047
# epoch: 198, training loss: 172.96942138671875, validation loss: 201.0217742919922
# epoch: 199, training loss: 180.58448791503906, validation loss: 204.62435913085938
# epoch: 200, training loss: 175.9311981201172, validation loss: 204.24411010742188
# epoch: 201, training loss: 117.18008422851562, validation loss: 192.3409423828125
# epoch: 202, training loss: 131.9221954345703, validation loss: 185.3184356689453
# epoch: 203, training loss: 139.19497680664062, validation loss: 189.00448608398438
# epoch: 204, training loss: 143.87200927734375, validation loss: 184.92236328125
# epoch: 205, training loss: 146.88800048828125, validation loss: 191.38037109375
# epoch: 206, training loss: 153.49508666992188, validation loss: 186.3043670654297
# epoch: 207, training loss: 135.94549560546875, validation loss: 182.43017578125
# epoch: 208, training loss: 144.37261962890625, validation loss: 182.98524475097656
# epoch: 209, training loss: 146.14974975585938, validation loss: 183.02552795410156
# epoch: 210, training loss: 146.6735382080078, validation loss: 184.0015869140625
# epoch: 211, training loss: 142.30349731445312, validation loss: 183.2743682861328
# epoch: 212, training loss: 142.2864227294922, validation loss: 180.91639709472656
# epoch: 213, training loss: 141.53330993652344, validation loss: 184.37777709960938
# epoch: 214, training loss: 146.5918426513672, validation loss: 181.28578186035156
# epoch: 215, training loss: 133.71548461914062, validation loss: 179.17018127441406
# epoch: 216, training loss: 143.15794372558594, validation loss: 179.0511932373047
# epoch: 217, training loss: 128.9445037841797, validation loss: 178.78041076660156
# epoch: 218, training loss: 143.26837158203125, validation loss: 180.28924560546875
# epoch: 219, training loss: 138.1372833251953, validation loss: 181.7146453857422
# epoch: 220, training loss: 140.90951538085938, validation loss: 178.7337646484375
# epoch: 221, training loss: 144.7654266357422, validation loss: 181.28895568847656
# epoch: 222, training loss: 145.13002014160156, validation loss: 178.30484008789062
# epoch: 223, training loss: 140.03587341308594, validation loss: 182.72096252441406
# epoch: 224, training loss: 137.2841796875, validation loss: 179.8426971435547
# epoch: 225, training loss: 137.50338745117188, validation loss: 176.81430053710938
# epoch: 226, training loss: 124.92801666259766, validation loss: 181.14198303222656
# epoch: 227, training loss: 131.83677673339844, validation loss: 175.6179656982422
# epoch: 228, training loss: 129.8993682861328, validation loss: 174.03077697753906
# epoch: 229, training loss: 140.43080139160156, validation loss: 178.4932861328125
# epoch: 230, training loss: 148.65426635742188, validation loss: 178.1363525390625
# epoch: 231, training loss: 126.4086685180664, validation loss: 178.46347045898438
# epoch: 232, training loss: 129.29771423339844, validation loss: 176.32882690429688
# epoch: 233, training loss: 127.80381774902344, validation loss: 173.89755249023438
# epoch: 234, training loss: 135.4689178466797, validation loss: 173.33526611328125
# epoch: 235, training loss: 134.47933959960938, validation loss: 173.8866424560547
# epoch: 236, training loss: 126.01342010498047, validation loss: 176.63270568847656
# epoch: 237, training loss: 135.89886474609375, validation loss: 178.36459350585938
# epoch: 238, training loss: 130.85565185546875, validation loss: 178.35604858398438
# epoch: 239, training loss: 121.26764678955078, validation loss: 174.0732421875
# epoch: 240, training loss: 130.55166625976562, validation loss: 176.1325225830078
# epoch: 241, training loss: 131.45736694335938, validation loss: 176.0637969970703
# epoch: 242, training loss: 125.43114471435547, validation loss: 174.64913940429688
# epoch: 243, training loss: 130.8188934326172, validation loss: 180.14918518066406
# epoch: 244, training loss: 128.22608947753906, validation loss: 181.72409057617188
# epoch: 245, training loss: 130.98377990722656, validation loss: 174.9827117919922
# epoch: 246, training loss: 130.33287048339844, validation loss: 173.7587127685547
# epoch: 247, training loss: 131.63290405273438, validation loss: 177.0186309814453
# epoch: 248, training loss: 127.3084716796875, validation loss: 176.4366912841797
# epoch: 249, training loss: 121.58446502685547, validation loss: 177.1064910888672
# epoch: 250, training loss: 124.0431137084961, validation loss: 174.4868621826172
# epoch: 251, training loss: 133.2347869873047, validation loss: 177.7773895263672
# epoch: 252, training loss: 123.74429321289062, validation loss: 176.466552734375
# epoch: 253, training loss: 123.10778045654297, validation loss: 176.91954040527344
# epoch: 254, training loss: 120.73979187011719, validation loss: 178.46905517578125
# epoch: 255, training loss: 124.86654663085938, validation loss: 176.54962158203125
# epoch: 256, training loss: 119.39752960205078, validation loss: 174.3692169189453
# epoch: 257, training loss: 126.4867172241211, validation loss: 172.72567749023438
# epoch: 258, training loss: 123.94843292236328, validation loss: 173.597900390625
# epoch: 259, training loss: 119.7164535522461, validation loss: 171.14549255371094
# epoch: 260, training loss: 124.85916137695312, validation loss: 168.62413024902344
# epoch: 261, training loss: 116.54035186767578, validation loss: 176.2427215576172
# epoch: 262, training loss: 115.71382904052734, validation loss: 177.10594177246094
# epoch: 263, training loss: 113.37525177001953, validation loss: 178.70455932617188
# epoch: 264, training loss: 116.08184051513672, validation loss: 178.73233032226562
# epoch: 265, training loss: 114.12654876708984, validation loss: 183.3411407470703
# epoch: 266, training loss: 115.52689361572266, validation loss: 176.9149627685547
# epoch: 267, training loss: 116.73992156982422, validation loss: 177.8599853515625
# epoch: 268, training loss: 116.03540802001953, validation loss: 177.31072998046875
# epoch: 269, training loss: 116.75263977050781, validation loss: 176.75970458984375
# epoch: 270, training loss: 114.66803741455078, validation loss: 172.65284729003906
# epoch: 271, training loss: 111.56315612792969, validation loss: 176.39425659179688
# epoch: 272, training loss: 111.56755065917969, validation loss: 173.9765167236328
# epoch: 273, training loss: 111.60708618164062, validation loss: 169.8959197998047
# epoch: 274, training loss: 111.17340087890625, validation loss: 174.95919799804688
# epoch: 275, training loss: 112.5722427368164, validation loss: 170.0916748046875
# epoch: 276, training loss: 113.47746276855469, validation loss: 171.4556427001953
# epoch: 277, training loss: 112.32960510253906, validation loss: 170.99627685546875
# epoch: 278, training loss: 110.38783264160156, validation loss: 172.90948486328125
# epoch: 279, training loss: 114.29747009277344, validation loss: 174.46942138671875
# epoch: 280, training loss: 117.01435852050781, validation loss: 168.55905151367188
# epoch: 281, training loss: 112.77957916259766, validation loss: 171.40237426757812
# epoch: 282, training loss: 112.39543151855469, validation loss: 167.4514617919922
# epoch: 283, training loss: 115.81719970703125, validation loss: 168.88864135742188
# epoch: 284, training loss: 113.45196533203125, validation loss: 172.1897430419922
# epoch: 285, training loss: 112.75909423828125, validation loss: 174.42941284179688
# epoch: 286, training loss: 114.44165802001953, validation loss: 174.7344512939453
# epoch: 287, training loss: 113.61705017089844, validation loss: 172.41156005859375
# epoch: 288, training loss: 114.737060546875, validation loss: 168.3762664794922
# epoch: 289, training loss: 114.47312927246094, validation loss: 172.86517333984375
# epoch: 290, training loss: 115.4029769897461, validation loss: 168.79949951171875
# epoch: 291, training loss: 110.52606201171875, validation loss: 172.22113037109375
# epoch: 292, training loss: 110.68492126464844, validation loss: 169.6298370361328
# epoch: 293, training loss: 112.93280029296875, validation loss: 169.90692138671875
# epoch: 294, training loss: 111.15559387207031, validation loss: 169.73548889160156
# epoch: 295, training loss: 113.71466827392578, validation loss: 168.7894287109375
# epoch: 296, training loss: 110.3064193725586, validation loss: 172.8272247314453
# epoch: 297, training loss: 109.59261322021484, validation loss: 168.756103515625
# epoch: 298, training loss: 111.75408935546875, validation loss: 170.2741241455078
# epoch: 299, training loss: 113.95220184326172, validation loss: 176.64437866210938
# epoch: 300, training loss: 112.77008819580078, validation loss: 170.06918334960938
#
# Done printing austin predictions
# ----------------------------------------------------------------------
# epoch: 1, training loss: 1432.0157470703125, validation loss: 185.00950622558594
# epoch: 2, training loss: 2226.690673828125, validation loss: 123.55311584472656
# epoch: 3, training loss: 560.384521484375, validation loss: 79.44879150390625
# epoch: 4, training loss: 2566.827392578125, validation loss: 144.953369140625
# epoch: 5, training loss: 403.3983459472656, validation loss: 80.75645446777344
# epoch: 6, training loss: 1038.9537353515625, validation loss: 212.43331909179688
# epoch: 7, training loss: 1614.23291015625, validation loss: 212.15370178222656
# epoch: 8, training loss: 1188.7625732421875, validation loss: 140.61900329589844
# epoch: 9, training loss: 2228.188232421875, validation loss: 143.7208251953125
# epoch: 10, training loss: 410.3076171875, validation loss: 95.36241912841797
# epoch: 11, training loss: 483.04522705078125, validation loss: 102.18995666503906
# epoch: 12, training loss: 2076.81005859375, validation loss: 165.42559814453125
# epoch: 13, training loss: 304.08746337890625, validation loss: 73.1069564819336
# epoch: 14, training loss: 2227.338134765625, validation loss: 143.56031799316406
# epoch: 15, training loss: 196.73497009277344, validation loss: 73.98884582519531
# epoch: 16, training loss: 342.66925048828125, validation loss: 81.15849304199219
# epoch: 17, training loss: 1341.846923828125, validation loss: 88.50599670410156
# epoch: 18, training loss: 310.646240234375, validation loss: 88.33431243896484
# epoch: 19, training loss: 653.676513671875, validation loss: 91.18988800048828
# epoch: 20, training loss: 664.635009765625, validation loss: 89.71317291259766
# epoch: 21, training loss: 1249.2633056640625, validation loss: 103.84971618652344
# epoch: 22, training loss: 318.0973205566406, validation loss: 80.77924346923828
# epoch: 23, training loss: 603.1439208984375, validation loss: 81.7579574584961
# epoch: 24, training loss: 1029.150390625, validation loss: 101.84232330322266
# epoch: 25, training loss: 416.0784912109375, validation loss: 75.34960174560547
# epoch: 26, training loss: 735.1908569335938, validation loss: 91.29396057128906
# epoch: 27, training loss: 371.4269714355469, validation loss: 86.06271362304688
# epoch: 28, training loss: 964.7461547851562, validation loss: 89.65255737304688
# epoch: 29, training loss: 265.7740173339844, validation loss: 89.46393585205078
# epoch: 30, training loss: 544.7586669921875, validation loss: 79.81831359863281
# epoch: 31, training loss: 631.4911499023438, validation loss: 79.95138549804688
# epoch: 32, training loss: 453.632568359375, validation loss: 72.52985382080078
# epoch: 33, training loss: 1208.99658203125, validation loss: 96.67803955078125
# epoch: 34, training loss: 268.31671142578125, validation loss: 90.4435806274414
# epoch: 35, training loss: 464.3524169921875, validation loss: 82.76456451416016
# epoch: 36, training loss: 948.009521484375, validation loss: 90.37687683105469
# epoch: 37, training loss: 243.9567413330078, validation loss: 87.61932373046875
# epoch: 38, training loss: 368.8512878417969, validation loss: 83.65360260009766
# epoch: 39, training loss: 543.0956420898438, validation loss: 77.0738525390625
# epoch: 40, training loss: 377.7048645019531, validation loss: 79.5484619140625
# epoch: 41, training loss: 559.8915405273438, validation loss: 77.62445068359375
# epoch: 42, training loss: 374.7182312011719, validation loss: 86.18998718261719
# epoch: 43, training loss: 615.565185546875, validation loss: 78.79810333251953
# epoch: 44, training loss: 328.8418884277344, validation loss: 69.97493743896484
# epoch: 45, training loss: 303.20550537109375, validation loss: 70.17789459228516
# epoch: 46, training loss: 399.41168212890625, validation loss: 66.39400482177734
# epoch: 47, training loss: 369.4872131347656, validation loss: 69.95850372314453
# epoch: 48, training loss: 248.9029541015625, validation loss: 89.42628479003906
# epoch: 49, training loss: 243.58335876464844, validation loss: 90.13545989990234
# epoch: 50, training loss: 284.1888732910156, validation loss: 71.5064697265625
# epoch: 51, training loss: 518.5599365234375, validation loss: 73.47738647460938
# epoch: 52, training loss: 252.15484619140625, validation loss: 71.5799560546875
# epoch: 53, training loss: 231.7515869140625, validation loss: 76.61494445800781
# epoch: 54, training loss: 242.06594848632812, validation loss: 79.71281433105469
# epoch: 55, training loss: 246.38526916503906, validation loss: 76.27622985839844
# epoch: 56, training loss: 312.53692626953125, validation loss: 70.12442016601562
# epoch: 57, training loss: 351.97021484375, validation loss: 68.32247161865234
# epoch: 58, training loss: 233.31906127929688, validation loss: 68.73863983154297
# epoch: 59, training loss: 205.25790405273438, validation loss: 74.94775390625
# epoch: 60, training loss: 199.980224609375, validation loss: 83.87255859375
# epoch: 61, training loss: 229.57327270507812, validation loss: 90.58595275878906
# epoch: 62, training loss: 188.0926513671875, validation loss: 85.28773498535156
# epoch: 63, training loss: 199.6266632080078, validation loss: 92.99765014648438
# epoch: 64, training loss: 274.490234375, validation loss: 65.67952728271484
# epoch: 65, training loss: 197.03440856933594, validation loss: 88.80101776123047
# epoch: 66, training loss: 212.6054229736328, validation loss: 94.76742553710938
# epoch: 67, training loss: 262.0527038574219, validation loss: 73.86260223388672
# epoch: 68, training loss: 204.8828582763672, validation loss: 71.13103485107422
# epoch: 69, training loss: 240.14227294921875, validation loss: 98.52286529541016
# epoch: 70, training loss: 220.46067810058594, validation loss: 93.20315551757812
# epoch: 71, training loss: 214.47552490234375, validation loss: 95.6275405883789
# epoch: 72, training loss: 218.82159423828125, validation loss: 91.12576293945312
# epoch: 73, training loss: 271.3915710449219, validation loss: 66.38573455810547
# epoch: 74, training loss: 208.94613647460938, validation loss: 70.24044036865234
# epoch: 75, training loss: 192.0609893798828, validation loss: 87.18321990966797
# epoch: 76, training loss: 235.97479248046875, validation loss: 94.23180389404297
# epoch: 77, training loss: 210.4616241455078, validation loss: 90.08350372314453
# epoch: 78, training loss: 283.9257507324219, validation loss: 110.28043365478516
# epoch: 79, training loss: 229.687255859375, validation loss: 92.00811004638672
# epoch: 80, training loss: 243.24378967285156, validation loss: 99.87238311767578
# epoch: 81, training loss: 301.8707275390625, validation loss: 112.376953125
# epoch: 82, training loss: 243.28993225097656, validation loss: 97.91387176513672
# epoch: 83, training loss: 185.7877655029297, validation loss: 85.08246612548828
# epoch: 84, training loss: 202.1249237060547, validation loss: 87.69479370117188
# epoch: 85, training loss: 204.97962951660156, validation loss: 93.66553497314453
# epoch: 86, training loss: 196.9029998779297, validation loss: 90.36518859863281
# epoch: 87, training loss: 196.42276000976562, validation loss: 81.38907623291016
# epoch: 88, training loss: 296.6516418457031, validation loss: 114.02730560302734
# epoch: 89, training loss: 306.4151306152344, validation loss: 109.51667022705078
# epoch: 90, training loss: 190.52719116210938, validation loss: 88.4635238647461
# epoch: 91, training loss: 195.7919464111328, validation loss: 92.29536437988281
# epoch: 92, training loss: 206.31980895996094, validation loss: 95.6468276977539
# epoch: 93, training loss: 156.9765625, validation loss: 86.22378540039062
# epoch: 94, training loss: 222.0639190673828, validation loss: 98.09420013427734
# epoch: 95, training loss: 215.31466674804688, validation loss: 96.8818588256836
# epoch: 96, training loss: 187.40174865722656, validation loss: 88.12698364257812
# epoch: 97, training loss: 188.44131469726562, validation loss: 84.04170227050781
# epoch: 98, training loss: 198.50209045410156, validation loss: 88.79169464111328
# epoch: 99, training loss: 189.7691650390625, validation loss: 71.90283966064453
# epoch: 100, training loss: 173.328369140625, validation loss: 78.63227844238281
# epoch: 101, training loss: 224.68020629882812, validation loss: 94.85875701904297
# epoch: 102, training loss: 199.3410186767578, validation loss: 90.26860046386719
# epoch: 103, training loss: 180.0952606201172, validation loss: 85.28782653808594
# epoch: 104, training loss: 182.64488220214844, validation loss: 84.62657165527344
# epoch: 105, training loss: 171.8958282470703, validation loss: 84.57215881347656
# epoch: 106, training loss: 251.9846954345703, validation loss: 103.8890151977539
# epoch: 107, training loss: 177.9647216796875, validation loss: 83.10059356689453
# epoch: 108, training loss: 216.7425537109375, validation loss: 91.3891372680664
# epoch: 109, training loss: 214.4894256591797, validation loss: 93.4646224975586
# epoch: 110, training loss: 171.65234375, validation loss: 81.17473602294922
# epoch: 111, training loss: 253.9390106201172, validation loss: 107.77335357666016
# epoch: 112, training loss: 243.42526245117188, validation loss: 102.90554809570312
# epoch: 113, training loss: 228.10833740234375, validation loss: 101.97945404052734
# epoch: 114, training loss: 175.7197723388672, validation loss: 85.62528228759766
# epoch: 115, training loss: 163.66465759277344, validation loss: 87.34039306640625
# epoch: 116, training loss: 235.2278289794922, validation loss: 102.04083251953125
# epoch: 117, training loss: 173.30909729003906, validation loss: 88.63980102539062
# epoch: 118, training loss: 276.0323486328125, validation loss: 103.36161041259766
# epoch: 119, training loss: 188.27565002441406, validation loss: 88.21385955810547
# epoch: 120, training loss: 222.31956481933594, validation loss: 84.02592468261719
# epoch: 121, training loss: 181.32476806640625, validation loss: 83.0642318725586
# epoch: 122, training loss: 250.3105010986328, validation loss: 110.8206558227539
# epoch: 123, training loss: 230.29261779785156, validation loss: 87.91278839111328
# epoch: 124, training loss: 211.3102264404297, validation loss: 96.9218521118164
# epoch: 125, training loss: 231.18519592285156, validation loss: 98.64105224609375
# epoch: 126, training loss: 213.15594482421875, validation loss: 88.75030517578125
# epoch: 127, training loss: 167.3289794921875, validation loss: 86.07920837402344
# epoch: 128, training loss: 158.278564453125, validation loss: 83.16812133789062
# epoch: 129, training loss: 154.41290283203125, validation loss: 93.16587829589844
# epoch: 130, training loss: 172.18450927734375, validation loss: 91.83003234863281
# epoch: 131, training loss: 183.63819885253906, validation loss: 87.25756072998047
# epoch: 132, training loss: 210.05458068847656, validation loss: 92.18612670898438
# epoch: 133, training loss: 192.54574584960938, validation loss: 92.13287353515625
# epoch: 134, training loss: 167.86834716796875, validation loss: 83.7466049194336
# epoch: 135, training loss: 215.649658203125, validation loss: 97.77909088134766
# epoch: 136, training loss: 153.1714630126953, validation loss: 79.16485595703125
# epoch: 137, training loss: 181.88340759277344, validation loss: 92.15409851074219
# epoch: 138, training loss: 182.4168243408203, validation loss: 90.71834564208984
# epoch: 139, training loss: 171.91278076171875, validation loss: 82.48468017578125
# epoch: 140, training loss: 157.48121643066406, validation loss: 78.71549224853516
# epoch: 141, training loss: 176.69847106933594, validation loss: 90.40192413330078
# epoch: 142, training loss: 173.65878295898438, validation loss: 82.98665618896484
# epoch: 143, training loss: 174.41639709472656, validation loss: 91.89566040039062
# epoch: 144, training loss: 143.08607482910156, validation loss: 78.65557861328125
# epoch: 145, training loss: 169.07652282714844, validation loss: 85.23741912841797
# epoch: 146, training loss: 208.64830017089844, validation loss: 95.27821350097656
# epoch: 147, training loss: 189.2394256591797, validation loss: 100.30177307128906
# epoch: 148, training loss: 226.77548217773438, validation loss: 99.31246948242188
# epoch: 149, training loss: 244.01731872558594, validation loss: 95.11326599121094
# epoch: 150, training loss: 159.0903778076172, validation loss: 83.66268920898438
# epoch: 151, training loss: 169.91964721679688, validation loss: 84.5984115600586
# epoch: 152, training loss: 172.4698486328125, validation loss: 88.95401000976562
# epoch: 153, training loss: 162.5715789794922, validation loss: 84.2564697265625
# epoch: 154, training loss: 190.20297241210938, validation loss: 90.52266693115234
# epoch: 155, training loss: 182.40060424804688, validation loss: 101.25684356689453
# epoch: 156, training loss: 161.87515258789062, validation loss: 84.56067657470703
# epoch: 157, training loss: 146.70823669433594, validation loss: 79.75250244140625
# epoch: 158, training loss: 243.10044860839844, validation loss: 105.87547302246094
# epoch: 159, training loss: 195.04420471191406, validation loss: 93.58200073242188
# epoch: 160, training loss: 320.2240295410156, validation loss: 105.68891906738281
# epoch: 161, training loss: 220.10780334472656, validation loss: 89.42938995361328
# epoch: 162, training loss: 214.5270538330078, validation loss: 91.24585723876953
# epoch: 163, training loss: 241.62530517578125, validation loss: 98.049072265625
# epoch: 164, training loss: 213.19371032714844, validation loss: 95.85813903808594
# epoch: 165, training loss: 182.28855895996094, validation loss: 76.46068572998047
# epoch: 166, training loss: 217.3070831298828, validation loss: 95.60720825195312
# epoch: 167, training loss: 208.4359893798828, validation loss: 99.51472473144531
# epoch: 168, training loss: 207.75205993652344, validation loss: 107.14037322998047
# epoch: 169, training loss: 195.41261291503906, validation loss: 92.27972412109375
# epoch: 170, training loss: 221.17697143554688, validation loss: 103.87702941894531
# epoch: 171, training loss: 274.16522216796875, validation loss: 107.88167572021484
# epoch: 172, training loss: 330.17474365234375, validation loss: 109.85665893554688
# epoch: 173, training loss: 196.96685791015625, validation loss: 88.74946594238281
# epoch: 174, training loss: 254.18736267089844, validation loss: 96.45500946044922
# epoch: 175, training loss: 302.45123291015625, validation loss: 107.23382568359375
# epoch: 176, training loss: 219.05393981933594, validation loss: 98.01702880859375
# epoch: 177, training loss: 252.89242553710938, validation loss: 107.855712890625
# epoch: 178, training loss: 253.14564514160156, validation loss: 102.74819946289062
# epoch: 179, training loss: 248.94833374023438, validation loss: 101.00665283203125
# epoch: 180, training loss: 230.7612762451172, validation loss: 97.78482818603516
# epoch: 181, training loss: 268.84417724609375, validation loss: 111.7813720703125
# epoch: 182, training loss: 208.0558319091797, validation loss: 96.30850219726562
# epoch: 183, training loss: 189.14234924316406, validation loss: 101.07782745361328
# epoch: 184, training loss: 247.45375061035156, validation loss: 110.93372344970703
# epoch: 185, training loss: 185.3192596435547, validation loss: 97.32411193847656
# epoch: 186, training loss: 164.12705993652344, validation loss: 87.93608856201172
# epoch: 187, training loss: 189.52867126464844, validation loss: 95.97657775878906
# epoch: 188, training loss: 171.848388671875, validation loss: 87.55095672607422
# epoch: 189, training loss: 227.8491668701172, validation loss: 109.70320129394531
# epoch: 190, training loss: 278.0910339355469, validation loss: 111.2356185913086
# epoch: 191, training loss: 219.27537536621094, validation loss: 98.45292663574219
# epoch: 192, training loss: 266.8791809082031, validation loss: 108.27978515625
# epoch: 193, training loss: 253.84107971191406, validation loss: 110.13785552978516
# epoch: 194, training loss: 201.03318786621094, validation loss: 96.76921081542969
# epoch: 195, training loss: 219.54185485839844, validation loss: 103.43946838378906
# epoch: 196, training loss: 190.19522094726562, validation loss: 97.28901672363281
# epoch: 197, training loss: 150.81951904296875, validation loss: 87.54788208007812
# epoch: 198, training loss: 273.20147705078125, validation loss: 111.49471282958984
# epoch: 199, training loss: 251.89820861816406, validation loss: 96.37055206298828
# epoch: 200, training loss: 215.97280883789062, validation loss: 100.91925811767578
# epoch: 201, training loss: 140.40374755859375, validation loss: 73.61693572998047
# epoch: 202, training loss: 152.32936096191406, validation loss: 80.95238494873047
# epoch: 203, training loss: 193.9220428466797, validation loss: 87.28053283691406
# epoch: 204, training loss: 200.03155517578125, validation loss: 90.76840209960938
# epoch: 205, training loss: 161.87249755859375, validation loss: 75.71599578857422
# epoch: 206, training loss: 180.1489715576172, validation loss: 79.9381332397461
# epoch: 207, training loss: 162.93226623535156, validation loss: 78.25159454345703
# epoch: 208, training loss: 142.9640655517578, validation loss: 76.7044677734375
# epoch: 209, training loss: 164.9269256591797, validation loss: 88.96656799316406
# epoch: 210, training loss: 218.00674438476562, validation loss: 96.0231704711914
# epoch: 211, training loss: 195.13424682617188, validation loss: 87.6637954711914
# epoch: 212, training loss: 194.34068298339844, validation loss: 82.6216049194336
# epoch: 213, training loss: 147.99766540527344, validation loss: 78.09274291992188
# epoch: 214, training loss: 202.91268920898438, validation loss: 82.23471069335938
# epoch: 215, training loss: 166.79554748535156, validation loss: 86.09566497802734
# epoch: 216, training loss: 186.92234802246094, validation loss: 92.20025634765625
# epoch: 217, training loss: 175.7769012451172, validation loss: 83.9314193725586
# epoch: 218, training loss: 182.80882263183594, validation loss: 84.8536148071289
# epoch: 219, training loss: 158.8355712890625, validation loss: 83.32197570800781
# epoch: 220, training loss: 162.92173767089844, validation loss: 80.11697387695312
# epoch: 221, training loss: 154.64398193359375, validation loss: 86.34855651855469
# epoch: 222, training loss: 179.43215942382812, validation loss: 84.2924575805664
# epoch: 223, training loss: 181.10009765625, validation loss: 88.5344467163086
# epoch: 224, training loss: 170.9199981689453, validation loss: 90.75985717773438
# epoch: 225, training loss: 169.16136169433594, validation loss: 78.65106201171875
# epoch: 226, training loss: 147.24085998535156, validation loss: 75.76730346679688
# epoch: 227, training loss: 159.38807678222656, validation loss: 78.17402648925781
# epoch: 228, training loss: 161.93995666503906, validation loss: 85.33039855957031
# epoch: 229, training loss: 172.5596923828125, validation loss: 86.83565521240234
# epoch: 230, training loss: 139.90371704101562, validation loss: 76.12481689453125
# epoch: 231, training loss: 144.8026885986328, validation loss: 74.43008422851562
# epoch: 232, training loss: 160.20957946777344, validation loss: 82.29566955566406
# epoch: 233, training loss: 192.66580200195312, validation loss: 92.0434799194336
# epoch: 234, training loss: 137.8182830810547, validation loss: 79.62842559814453
# epoch: 235, training loss: 170.08380126953125, validation loss: 89.39034271240234
# epoch: 236, training loss: 203.80230712890625, validation loss: 98.45197296142578
# epoch: 237, training loss: 172.91677856445312, validation loss: 90.9713363647461
# epoch: 238, training loss: 151.85311889648438, validation loss: 82.68185424804688
# epoch: 239, training loss: 157.16781616210938, validation loss: 85.45394897460938
# epoch: 240, training loss: 144.6873016357422, validation loss: 81.8182144165039
# epoch: 241, training loss: 180.54193115234375, validation loss: 97.8100814819336
# epoch: 242, training loss: 139.33799743652344, validation loss: 78.58563995361328
# epoch: 243, training loss: 156.49459838867188, validation loss: 84.64260864257812
# epoch: 244, training loss: 170.9217071533203, validation loss: 91.53044891357422
# epoch: 245, training loss: 165.292236328125, validation loss: 88.31436920166016
# epoch: 246, training loss: 169.22882080078125, validation loss: 88.5865249633789
# epoch: 247, training loss: 186.04100036621094, validation loss: 92.17984008789062
# epoch: 248, training loss: 216.0394287109375, validation loss: 92.88988494873047
# epoch: 249, training loss: 169.74969482421875, validation loss: 87.6361083984375
# epoch: 250, training loss: 198.2357940673828, validation loss: 86.61119842529297
# epoch: 251, training loss: 169.00079345703125, validation loss: 92.96337890625
# epoch: 252, training loss: 205.2699432373047, validation loss: 97.50574493408203
# epoch: 253, training loss: 148.48483276367188, validation loss: 77.71953582763672
# epoch: 254, training loss: 169.66632080078125, validation loss: 85.94644165039062
# epoch: 255, training loss: 162.46905517578125, validation loss: 82.866455078125
# epoch: 256, training loss: 166.91519165039062, validation loss: 86.36849975585938
# epoch: 257, training loss: 148.14842224121094, validation loss: 81.08309936523438
# epoch: 258, training loss: 177.65451049804688, validation loss: 94.30702209472656
# epoch: 259, training loss: 178.1884307861328, validation loss: 91.0893783569336
# epoch: 260, training loss: 186.1681671142578, validation loss: 89.16239929199219
# epoch: 261, training loss: 161.07557678222656, validation loss: 94.30011749267578
# epoch: 262, training loss: 138.19029235839844, validation loss: 83.50653076171875
# epoch: 263, training loss: 144.61439514160156, validation loss: 83.97586822509766
# epoch: 264, training loss: 181.4068145751953, validation loss: 94.78874206542969
# epoch: 265, training loss: 167.52383422851562, validation loss: 84.86663818359375
# epoch: 266, training loss: 163.01646423339844, validation loss: 84.22834777832031
# epoch: 267, training loss: 159.25106811523438, validation loss: 80.14617156982422
# epoch: 268, training loss: 189.59829711914062, validation loss: 87.14237213134766
# epoch: 269, training loss: 190.4960174560547, validation loss: 91.48434448242188
# epoch: 270, training loss: 157.78857421875, validation loss: 77.57304382324219
# epoch: 271, training loss: 149.86888122558594, validation loss: 82.64701080322266
# epoch: 272, training loss: 169.17681884765625, validation loss: 86.90638732910156
# epoch: 273, training loss: 162.54254150390625, validation loss: 88.42854309082031
# epoch: 274, training loss: 155.4725799560547, validation loss: 82.31861877441406
# epoch: 275, training loss: 164.11932373046875, validation loss: 92.00458526611328
# epoch: 276, training loss: 171.62811279296875, validation loss: 87.20476531982422
# epoch: 277, training loss: 151.4202117919922, validation loss: 88.3046875
# epoch: 278, training loss: 182.13983154296875, validation loss: 90.13580322265625
# epoch: 279, training loss: 145.39234924316406, validation loss: 84.23640441894531
# epoch: 280, training loss: 160.89398193359375, validation loss: 86.35069274902344
# epoch: 281, training loss: 182.68833923339844, validation loss: 87.35330963134766
# epoch: 282, training loss: 177.4650421142578, validation loss: 93.73619079589844
# epoch: 283, training loss: 148.94796752929688, validation loss: 87.84180450439453
# epoch: 284, training loss: 161.80575561523438, validation loss: 91.81561279296875
# epoch: 285, training loss: 170.79464721679688, validation loss: 92.53247833251953
# epoch: 286, training loss: 166.26663208007812, validation loss: 93.85371398925781
# epoch: 287, training loss: 166.0443572998047, validation loss: 83.45014953613281
# epoch: 288, training loss: 183.72061157226562, validation loss: 91.51802825927734
# epoch: 289, training loss: 176.36517333984375, validation loss: 81.48898315429688
# epoch: 290, training loss: 169.18624877929688, validation loss: 84.02693176269531
# ...
# epoch: 106, training loss: 92.77355194091797, validation loss: 142.71766662597656
# epoch: 107, training loss: 93.76011657714844, validation loss: 143.48602294921875
# epoch: 108, training loss: 93.37519836425781, validation loss: 144.37088012695312
# epoch: 109, training loss: 94.2771224975586, validation loss: 144.34603881835938
# epoch: 110, training loss: 94.53541564941406, validation loss: 143.1026611328125
# epoch: 111, training loss: 93.8265609741211, validation loss: 142.61322021484375
# epoch: 112, training loss: 94.18708801269531, validation loss: 143.209228515625
# epoch: 113, training loss: 92.97777557373047, validation loss: 144.11570739746094
# epoch: 114, training loss: 93.23420715332031, validation loss: 143.68299865722656
# epoch: 115, training loss: 92.05926513671875, validation loss: 145.40518188476562
# epoch: 116, training loss: 93.37977600097656, validation loss: 143.8648223876953
# epoch: 117, training loss: 93.7844009399414, validation loss: 142.89234924316406
# epoch: 118, training loss: 93.26769256591797, validation loss: 143.51376342773438
# epoch: 119, training loss: 93.29676818847656, validation loss: 145.2857666015625
# epoch: 120, training loss: 92.63128662109375, validation loss: 143.45074462890625
# epoch: 121, training loss: 93.3886489868164, validation loss: 144.154296875
# epoch: 122, training loss: 93.82267761230469, validation loss: 143.90003967285156
# epoch: 123, training loss: 92.54420471191406, validation loss: 142.72215270996094
# epoch: 124, training loss: 92.48165893554688, validation loss: 142.50857543945312
# epoch: 125, training loss: 92.90514373779297, validation loss: 143.67637634277344
# epoch: 126, training loss: 93.23773193359375, validation loss: 143.06805419921875
# epoch: 127, training loss: 93.72399139404297, validation loss: 143.37449645996094
# epoch: 128, training loss: 93.18817901611328, validation loss: 144.1943359375
# epoch: 129, training loss: 93.6449966430664, validation loss: 143.65103149414062
# epoch: 130, training loss: 93.61343383789062, validation loss: 144.58969116210938
# epoch: 131, training loss: 92.81996154785156, validation loss: 144.22775268554688
# epoch: 132, training loss: 92.82306671142578, validation loss: 142.63833618164062
# epoch: 133, training loss: 92.31000518798828, validation loss: 142.01344299316406
# epoch: 134, training loss: 93.2090835571289, validation loss: 143.48660278320312
# epoch: 135, training loss: 93.93597412109375, validation loss: 143.97247314453125
# epoch: 136, training loss: 92.73966979980469, validation loss: 143.72584533691406
# epoch: 137, training loss: 93.37227630615234, validation loss: 143.46958923339844
# epoch: 138, training loss: 93.18144989013672, validation loss: 143.97850036621094
# epoch: 139, training loss: 91.92597961425781, validation loss: 143.69606018066406
# epoch: 140, training loss: 92.81147766113281, validation loss: 143.16567993164062
# epoch: 141, training loss: 92.95893096923828, validation loss: 143.4609375
# epoch: 142, training loss: 93.06305694580078, validation loss: 142.68222045898438
# epoch: 143, training loss: 93.14463806152344, validation loss: 142.57164001464844
# epoch: 144, training loss: 93.64974975585938, validation loss: 143.83714294433594
# epoch: 145, training loss: 93.42965698242188, validation loss: 142.95501708984375
# epoch: 146, training loss: 92.56773376464844, validation loss: 143.4148406982422
# epoch: 147, training loss: 93.20555114746094, validation loss: 144.21372985839844
# epoch: 148, training loss: 92.4794692993164, validation loss: 143.4354248046875
# epoch: 149, training loss: 93.55754852294922, validation loss: 142.88900756835938
# epoch: 150, training loss: 93.4354019165039, validation loss: 142.40232849121094
# epoch: 151, training loss: 93.15960693359375, validation loss: 141.99476623535156
# epoch: 152, training loss: 93.38812255859375, validation loss: 143.38221740722656
# epoch: 153, training loss: 92.5678482055664, validation loss: 142.71041870117188
# epoch: 154, training loss: 92.70763397216797, validation loss: 142.37147521972656
# epoch: 155, training loss: 92.47716522216797, validation loss: 141.7916717529297
# epoch: 156, training loss: 92.11758422851562, validation loss: 142.14453125
# epoch: 157, training loss: 91.97130584716797, validation loss: 142.15419006347656
# epoch: 158, training loss: 93.71442413330078, validation loss: 140.7972412109375
# epoch: 159, training loss: 92.81038665771484, validation loss: 142.55844116210938
# epoch: 160, training loss: 93.60608673095703, validation loss: 142.32244873046875
# epoch: 161, training loss: 92.68792724609375, validation loss: 142.99978637695312
# epoch: 162, training loss: 92.06476593017578, validation loss: 142.2311248779297
# epoch: 163, training loss: 93.06194305419922, validation loss: 142.7978973388672
# epoch: 164, training loss: 93.65370178222656, validation loss: 142.00897216796875
# epoch: 165, training loss: 92.8056411743164, validation loss: 142.47869873046875
# epoch: 166, training loss: 93.15384674072266, validation loss: 141.80584716796875
# epoch: 167, training loss: 92.23651885986328, validation loss: 142.75718688964844
# epoch: 168, training loss: 92.57453155517578, validation loss: 142.0035858154297
# epoch: 169, training loss: 91.8654556274414, validation loss: 141.4055633544922
# epoch: 170, training loss: 92.63482666015625, validation loss: 142.10182189941406
# epoch: 171, training loss: 93.96014404296875, validation loss: 142.55430603027344
# epoch: 172, training loss: 92.40145111083984, validation loss: 142.19528198242188
# epoch: 173, training loss: 92.41097259521484, validation loss: 142.59384155273438
# epoch: 174, training loss: 92.53119659423828, validation loss: 141.97447204589844
# epoch: 175, training loss: 93.48038482666016, validation loss: 141.30628967285156
# epoch: 176, training loss: 94.4364242553711, validation loss: 140.61309814453125
# epoch: 177, training loss: 93.7424545288086, validation loss: 140.96884155273438
# epoch: 178, training loss: 93.1969985961914, validation loss: 140.00009155273438
# epoch: 179, training loss: 92.82787322998047, validation loss: 140.33065795898438
# epoch: 180, training loss: 92.09666442871094, validation loss: 142.2851104736328
# epoch: 181, training loss: 92.00330352783203, validation loss: 140.93629455566406
# epoch: 182, training loss: 92.3927230834961, validation loss: 140.42703247070312
# epoch: 183, training loss: 92.57087707519531, validation loss: 142.40869140625
# epoch: 184, training loss: 92.73239135742188, validation loss: 141.39761352539062
# epoch: 185, training loss: 94.24475860595703, validation loss: 141.57766723632812
# epoch: 186, training loss: 93.31754302978516, validation loss: 142.31996154785156
# epoch: 187, training loss: 92.95423126220703, validation loss: 142.99896240234375
# epoch: 188, training loss: 92.77705383300781, validation loss: 143.86489868164062
# epoch: 189, training loss: 92.72416687011719, validation loss: 142.38145446777344
# epoch: 190, training loss: 93.7176513671875, validation loss: 141.83956909179688
# epoch: 191, training loss: 92.83599090576172, validation loss: 142.21356201171875
# epoch: 192, training loss: 93.22747802734375, validation loss: 142.14695739746094
# epoch: 193, training loss: 91.64878845214844, validation loss: 142.63311767578125
# epoch: 194, training loss: 90.98699951171875, validation loss: 142.56192016601562
# epoch: 195, training loss: 90.80379486083984, validation loss: 143.73150634765625
# epoch: 196, training loss: 91.81439971923828, validation loss: 142.63108825683594
# epoch: 197, training loss: 90.7027816772461, validation loss: 141.9878387451172
# epoch: 198, training loss: 91.35680389404297, validation loss: 142.9687042236328
# epoch: 199, training loss: 91.46217346191406, validation loss: 141.49899291992188
# epoch: 200, training loss: 91.96514129638672, validation loss: 141.85772705078125
# epoch: 201, training loss: 92.8129653930664, validation loss: 141.50685119628906
# epoch: 202, training loss: 92.64423370361328, validation loss: 142.3280792236328
# epoch: 203, training loss: 91.95450592041016, validation loss: 143.02601623535156
# epoch: 204, training loss: 92.32359313964844, validation loss: 142.7451629638672
# epoch: 205, training loss: 91.48304748535156, validation loss: 141.5003662109375
# epoch: 206, training loss: 94.02885437011719, validation loss: 141.6475830078125
# epoch: 207, training loss: 93.33919525146484, validation loss: 140.9684295654297
# epoch: 208, training loss: 92.52023315429688, validation loss: 141.56639099121094
# epoch: 209, training loss: 93.13158416748047, validation loss: 142.28713989257812
# epoch: 210, training loss: 93.2685546875, validation loss: 142.43698120117188
# epoch: 211, training loss: 94.4261703491211, validation loss: 143.5117645263672
# epoch: 212, training loss: 93.57476806640625, validation loss: 143.39697265625
# epoch: 213, training loss: 93.05235290527344, validation loss: 143.27272033691406
# epoch: 214, training loss: 93.35838317871094, validation loss: 142.84803771972656
# epoch: 215, training loss: 92.23863220214844, validation loss: 142.9282989501953
# epoch: 216, training loss: 92.0294189453125, validation loss: 143.00901794433594
# epoch: 217, training loss: 91.99172973632812, validation loss: 142.30967712402344
# epoch: 218, training loss: 90.9245834350586, validation loss: 142.71304321289062
# epoch: 219, training loss: 91.23149108886719, validation loss: 142.38636779785156
# epoch: 220, training loss: 91.66761779785156, validation loss: 142.88600158691406
# epoch: 221, training loss: 91.01280212402344, validation loss: 141.47994995117188
# epoch: 222, training loss: 91.1082763671875, validation loss: 141.18202209472656
# epoch: 223, training loss: 91.62429809570312, validation loss: 141.57647705078125
# epoch: 224, training loss: 92.49290466308594, validation loss: 141.31468200683594
# epoch: 225, training loss: 93.16645050048828, validation loss: 140.23565673828125
# epoch: 226, training loss: 92.26207733154297, validation loss: 140.19479370117188
# epoch: 227, training loss: 92.52262878417969, validation loss: 140.46034240722656
# epoch: 228, training loss: 92.84832000732422, validation loss: 139.7465362548828
# epoch: 229, training loss: 92.2716293334961, validation loss: 141.15977478027344
# epoch: 230, training loss: 92.24063110351562, validation loss: 142.10337829589844
# epoch: 231, training loss: 92.54696655273438, validation loss: 140.9446258544922
# epoch: 232, training loss: 91.58747863769531, validation loss: 139.82862854003906
# epoch: 233, training loss: 91.31965637207031, validation loss: 140.57952880859375
# epoch: 234, training loss: 91.43751525878906, validation loss: 140.65008544921875
# epoch: 235, training loss: 91.67729949951172, validation loss: 140.13494873046875
# epoch: 236, training loss: 91.95215606689453, validation loss: 140.9204559326172
# epoch: 237, training loss: 93.28642272949219, validation loss: 141.70028686523438
# epoch: 238, training loss: 92.72284698486328, validation loss: 141.95228576660156
# epoch: 239, training loss: 92.57713317871094, validation loss: 141.16700744628906
# epoch: 240, training loss: 92.40371704101562, validation loss: 141.0178680419922
# epoch: 241, training loss: 92.29491424560547, validation loss: 141.11361694335938
# epoch: 242, training loss: 91.9396743774414, validation loss: 141.5638427734375
# epoch: 243, training loss: 92.27852630615234, validation loss: 142.81011962890625
# epoch: 244, training loss: 91.94034576416016, validation loss: 143.00917053222656
# epoch: 245, training loss: 92.5023193359375, validation loss: 142.37399291992188
# epoch: 246, training loss: 93.40716552734375, validation loss: 141.8534698486328
# epoch: 247, training loss: 93.63158416748047, validation loss: 141.5623321533203
# epoch: 248, training loss: 92.61632537841797, validation loss: 142.11517333984375
# epoch: 249, training loss: 93.47804260253906, validation loss: 142.45484924316406
# epoch: 250, training loss: 93.2705307006836, validation loss: 143.334716796875
# epoch: 251, training loss: 94.3316650390625, validation loss: 143.40968322753906
# epoch: 252, training loss: 93.47801971435547, validation loss: 142.13108825683594
# epoch: 253, training loss: 93.75830841064453, validation loss: 142.35604858398438
# epoch: 254, training loss: 93.30621337890625, validation loss: 141.89410400390625
# epoch: 255, training loss: 92.8835678100586, validation loss: 141.8070831298828
# epoch: 256, training loss: 92.45195770263672, validation loss: 141.622314453125
# epoch: 257, training loss: 93.60786437988281, validation loss: 140.96226501464844
# epoch: 258, training loss: 94.0939712524414, validation loss: 141.4818878173828
# epoch: 259, training loss: 93.49665069580078, validation loss: 141.88619995117188
# epoch: 260, training loss: 93.51725769042969, validation loss: 142.17510986328125
# epoch: 261, training loss: 93.33478546142578, validation loss: 140.0048065185547
# epoch: 262, training loss: 92.81040954589844, validation loss: 140.9728546142578
# epoch: 263, training loss: 92.11874389648438, validation loss: 140.55392456054688
# epoch: 264, training loss: 92.31764221191406, validation loss: 140.86097717285156
# epoch: 265, training loss: 92.38651275634766, validation loss: 140.65548706054688
# epoch: 266, training loss: 92.91747283935547, validation loss: 141.16445922851562
# epoch: 267, training loss: 92.97640228271484, validation loss: 141.87026977539062
# epoch: 268, training loss: 92.99613189697266, validation loss: 141.0069580078125
# epoch: 269, training loss: 93.2307357788086, validation loss: 141.1786346435547
# epoch: 270, training loss: 92.4834976196289, validation loss: 142.0069122314453
# epoch: 271, training loss: 92.82920837402344, validation loss: 142.35443115234375
# epoch: 272, training loss: 92.56884002685547, validation loss: 141.6787109375
# epoch: 273, training loss: 92.8428726196289, validation loss: 141.97731018066406
# epoch: 274, training loss: 92.70184326171875, validation loss: 141.64451599121094
# epoch: 275, training loss: 92.77647399902344, validation loss: 141.0038604736328
# epoch: 276, training loss: 93.12537384033203, validation loss: 140.7313232421875
# epoch: 277, training loss: 92.5023193359375, validation loss: 140.02316284179688
# epoch: 278, training loss: 92.25888061523438, validation loss: 141.07916259765625
# epoch: 279, training loss: 93.52738952636719, validation loss: 140.67291259765625
# epoch: 280, training loss: 93.85684204101562, validation loss: 141.68817138671875
# epoch: 281, training loss: 93.43638610839844, validation loss: 139.81211853027344
# epoch: 282, training loss: 92.6983642578125, validation loss: 140.94662475585938
# epoch: 283, training loss: 92.654541015625, validation loss: 139.90077209472656
# epoch: 284, training loss: 92.2611083984375, validation loss: 140.6564178466797
# epoch: 285, training loss: 92.6642837524414, validation loss: 140.52098083496094
# epoch: 286, training loss: 92.50091552734375, validation loss: 142.1595916748047
# epoch: 287, training loss: 91.9487075805664, validation loss: 141.17611694335938
# epoch: 288, training loss: 91.77672576904297, validation loss: 140.8131866455078
# epoch: 289, training loss: 92.41663360595703, validation loss: 140.07821655273438
# epoch: 290, training loss: 91.56620788574219, validation loss: 140.63441467285156
# epoch: 291, training loss: 93.15691375732422, validation loss: 141.5610809326172
# epoch: 292, training loss: 92.75365447998047, validation loss: 140.1395721435547
# epoch: 293, training loss: 92.22705078125, validation loss: 139.7001953125
# epoch: 294, training loss: 92.49786376953125, validation loss: 140.16928100585938
# epoch: 295, training loss: 92.34912109375, validation loss: 139.1213836669922
# epoch: 296, training loss: 92.54886627197266, validation loss: 140.3120880126953
# epoch: 297, training loss: 91.8812484741211, validation loss: 139.88182067871094
# epoch: 298, training loss: 91.81828308105469, validation loss: 138.96603393554688
# epoch: 299, training loss: 92.06214141845703, validation loss: 139.41851806640625
# epoch: 300, training loss: 92.1507568359375, validation loss: 139.7855987548828
#
# Done printing palo-alto predictions
# ----------------------------------------------------------------------
# ./submission.csv generated!
